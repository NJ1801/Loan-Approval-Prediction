# %%
## df.to_csv('cleaned_df.csv') to save file

# %%
import mysql.connector as sql

# %%
mydb = sql.connect(
    host="localhost",
    user="root",
    password="root@123",
    database = "pozent"
)

# %%
mycursor = mydb.cursor()

# %%
mycursor.execute("select * from employee")
result = mycursor.fetchall()
print(result)

# for x in result:
#     print(x)
# Out:
# [(1, 'Ram', 'ADMIN', 1000, 2, None), (2, 'Harini', 'MANAGER', 2500, 2, None), (3, 'George', 'SALES', 2000, 1, None), (4, 'Ramya', 'SALES', 1300, 2, None), (5, 'Meena', 'HR', 20000, 3, None), (6, 'Ashok', 'MANAGER', 3000, 1, None), (7, 'Abdul', 'HR', 20000, 1, None), (8, 'Ramya', 'ENGINEER', 10000, 2, None), (9, 'Raghu', 'CEO', 8000, 3, None), (10, 'Arvind', 'MANAGER', 280, 3, None), (11, 'Akshay', 'ENGINEER', 8888, 1, None), (12, 'John', 'ADMIN', 2200, 1, None), (13, 'Abinaya', 'ENGINEER', 2100, 2, None), (14, 'Vidya', 'ADMIN', 2200, None, None), (15, 'Ranjani', 'ENGINEER', 2100, None, None), (16, 'Sara', 'HR', 1800, 3, None), (17, 'Praveen', 'SALES', 1500, 2, None), (18, 'Deepak', 'ENGINEER', 2200, 1, None), (19, 'Neha', 'ADMIN', 1800, 3, None), (20, 'Manoj', 'HR', 1900, 1, None), (21, 'Priya', 'MANAGER', 2700, None, None), (22, 'Suresh', 'ENGINEER', 2300, 2, None), (23, 'Anu', 'SALES', 1600, 3, None), (24, 'Vivek', 'HR', 2000, None, None), (25, 'Kiran', 'ENGINEER', 2400, 1, None), 
# ...

# %%
import pandas as pd

# %%
df = pd.DataFrame(result)
df
# Out:
#      0          1         2      3    4     5
# 0    1        Ram     ADMIN   1000  2.0  None
# 1    2     Harini   MANAGER   2500  2.0  None
# 2    3     George     SALES   2000  1.0  None
# 3    4      Ramya     SALES   1300  2.0  None
# 4    5      Meena        HR  20000  3.0  None
# 5    6      Ashok   MANAGER   3000  1.0  None
# 6    7      Abdul        HR  20000  1.0  None
# 7    8      Ramya  ENGINEER  10000  2.0  None
# 8    9      Raghu       CEO   8000  3.0  None
# 9   10     Arvind   MANAGER    280  3.0  None
# 10  11     Akshay  ENGINEER   8888  1.0  None
# 11  12       John     ADMIN   2200  1.0  None
# 12  13    Abinaya  ENGINEER   2100  2.0  None
# 13  14      Vidya     ADMIN   2200  NaN  None
# 14  15    Ranjani  ENGINEER   2100  NaN  None
# 15  16       Sara        HR   1800  3.0  None
# 16  17    Praveen     SALES   1500  2.0  None
# 17  18     Deepak  ENGINEER   2200  1.0  None
# 18  19       Neha     ADMIN   1800  3.0  None
# ...

# %%
query = "select * from employee"
query
# Out:
# 'select * from employee'

# %%
df = pd.read_sql(query,mydb)
df
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_13552\2497262195.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query,mydb)
#     emp_id      ename  job_desc  salary  branch_id date_
# 0        1        Ram     ADMIN    1000        2.0  None
# 1        2     Harini   MANAGER    2500        2.0  None
# 2        3     George     SALES    2000        1.0  None
# 3        4      Ramya     SALES    1300        2.0  None
# 4        5      Meena        HR   20000        3.0  None
# 5        6      Ashok   MANAGER    3000        1.0  None
# 6        7      Abdul        HR   20000        1.0  None
# 7        8      Ramya  ENGINEER   10000        2.0  None
# 8        9      Raghu       CEO    8000        3.0  None
# 9       10     Arvind   MANAGER     280        3.0  None
# ...

# %%
print(df.shape)
# Out:
# (50, 6)

# %%
df.loc[1]
# Out:
# emp_id             2
# ename         Harini
# job_desc     MANAGER
# salary          2500
# branch_id        2.0
# date_           None
# Name: 1, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   emp_id     50 non-null     int64
#  1   ename      50 non-null     object
#  2   job_desc   50 non-null     object
#  3   salary     50 non-null     int64
#  4   branch_id  38 non-null     float64
#  5   date_      0 non-null      object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 2.5+ KB

# %%
mycursor.execute("update employee set salary = 8888 where emp_id = 11")
mycursor.execute("SELECT * FROM EMPLOYEE")
result = mycursor.fetchall()
mydb.cmd_refresh(1)
print(result)

# for x in result:
#     print(x)
# Out:
# [(1, 'Ram', 'ADMIN', 1000, 2, None), (2, 'Harini', 'MANAGER', 2500, 2, None), (3, 'George', 'SALES', 2000, 1, None), (4, 'Ramya', 'SALES', 1300, 2, None), (5, 'Meena', 'HR', 20000, 3, None), (6, 'Ashok', 'MANAGER', 3000, 1, None), (7, 'Abdul', 'HR', 20000, 1, None), (8, 'Ramya', 'ENGINEER', 10000, 2, None), (9, 'Raghu', 'CEO', 8000, 3, None), (10, 'Arvind', 'MANAGER', 280, 3, None), (11, 'Akshay', 'ENGINEER', 8888, 1, None), (12, 'John', 'ADMIN', 2200, 1, None), (13, 'Abinaya', 'ENGINEER', 2100, 2, None), (14, 'Vidya', 'ADMIN', 2200, None, None), (15, 'Ranjani', 'ENGINEER', 2100, None, None), (16, 'Sara', 'HR', 1800, 3, None), (17, 'Praveen', 'SALES', 1500, 2, None), (18, 'Deepak', 'ENGINEER', 2200, 1, None), (19, 'Neha', 'ADMIN', 1800, 3, None), (20, 'Manoj', 'HR', 1900, 1, None), (21, 'Priya', 'MANAGER', 2700, None, None), (22, 'Suresh', 'ENGINEER', 2300, 2, None), (23, 'Anu', 'SALES', 1600, 3, None), (24, 'Vivek', 'HR', 2000, None, None), (25, 'Kiran', 'ENGINEER', 2400, 1, None), 
# ...

# %% [markdown]
# # data preprocessing

# %%
print(df.head())
# Out:
#    emp_id   ename job_desc  salary  branch_id date_
# 0       1     Ram    ADMIN    1000        2.0  None
# 1       2  Harini  MANAGER    2500        2.0  None
# 2       3  George    SALES    2000        1.0  None
# 3       4   Ramya    SALES    1300        2.0  None
# 4       5   Meena       HR   20000        3.0  None

# %%
print(df.isnull().sum())
# Out:
# emp_id        0
# ename         0
# job_desc      0
# salary        0
# branch_id    12
# date_        50
# dtype: int64

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
#df.dropna()

# %%
df.drop_duplicates()
# Out:
#     emp_id      ename  job_desc  salary  branch_id date_
# 0        1        Ram     ADMIN    1000        2.0  None
# 1        2     Harini   MANAGER    2500        2.0  None
# 2        3     George     SALES    2000        1.0  None
# 3        4      Ramya     SALES    1300        2.0  None
# 4        5      Meena        HR   20000        3.0  None
# 5        6      Ashok   MANAGER    3000        1.0  None
# 6        7      Abdul        HR   20000        1.0  None
# 7        8      Ramya  ENGINEER   10000        2.0  None
# 8        9      Raghu       CEO    8000        3.0  None
# 9       10     Arvind   MANAGER     280        3.0  None
# 10      11     Akshay  ENGINEER    8888        1.0  None
# 11      12       John     ADMIN    2200        1.0  None
# 12      13    Abinaya  ENGINEER    2100        2.0  None
# 13      14      Vidya     ADMIN    2200        NaN  None
# 14      15    Ranjani  ENGINEER    2100        NaN  None
# ...

# %%
df.info()
mydb.cmd_refresh(1)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   emp_id     50 non-null     int64
#  1   ename      50 non-null     object
#  2   job_desc   50 non-null     object
#  3   salary     50 non-null     int64
#  4   branch_id  38 non-null     float64
#  5   date_      0 non-null      object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 2.5+ KB
# {'field_count': 0,
#  'affected_rows': 0,
#  'insert_id': 0,
#  'status_flag': 0,
#  'warning_count': 0}

# %%
# convert catagorical into numeric 
data=['job_desc']
for column in data:
    df[column] = pd.factorize(df[column])[0]
df
# Out:
#     emp_id      ename  job_desc  salary  branch_id date_
# 0        1        Ram         0    1000        2.0  None
# 1        2     Harini         1    2500        2.0  None
# 2        3     George         2    2000        1.0  None
# 3        4      Ramya         2    1300        2.0  None
# 4        5      Meena         3   20000        3.0  None
# 5        6      Ashok         1    3000        1.0  None
# 6        7      Abdul         3   20000        1.0  None
# 7        8      Ramya         4   10000        2.0  None
# 8        9      Raghu         5    8000        3.0  None
# 9       10     Arvind         1     280        3.0  None
# 10      11     Akshay         4    8888        1.0  None
# 11      12       John         0    2200        1.0  None
# 12      13    Abinaya         4    2100        2.0  None
# 13      14      Vidya         0    2200        NaN  None
# 14      15    Ranjani         4    2100        NaN  None
# ...

# %%
filt = df[df["salary"]<1000]
filt
# Out:
#    emp_id   ename  job_desc  salary  branch_id date_
# 9      10  Arvind         1     280        3.0  None

# %%
new_salary = df["new_salary"] = df["salary"]+500
new_salary
# Out:
# 0      1500
# 1      3000
# 2      2500
# 3      1800
# 4     20500
# 5      3500
# 6     20500
# 7     10500
# 8      8500
# 9       780
# 10     9388
# 11     2700
# 12     2600
# 13     2700
# 14     2600
# 15     2300
# 16     2000
# 17     2700
# 18     2300
# 19     2400
# 20     3200
# 21     2800
# 22     2100
# 23     2500
# 24     2900
# 25     2500
# 26     3000
# 27     2200
# 28     3300
# 29     2600
# 30     3100
# 31     2700
# 32     2300
# 33     2700
# 34     3400
# 35     3200
# 36     2800
# 37     2400
# 38     2800
# 39     3500
# 40     2376
# 41     2900
# 42     2500
# 43     2900
# 44     3600
# 45     3400
# 46     3000
# 47     2600
# 48     3000
# 49     3700
# Name: salary, dtype: int64

# %%
mea = df["salary"].mean()
mea
# Out:
# 3314.88

# %%
med = df["branch_id"].median()
med
# Out:
# 2.0

# %%
mod = df["branch_id"].mode()[0]
mod
# Out:
# 2.0

# %%
df
# Out:
#     emp_id      ename  job_desc  salary  branch_id date_  new_salary
# 0        1        Ram         0    1000        2.0  None        1500
# 1        2     Harini         1    2500        2.0  None        3000
# 2        3     George         2    2000        1.0  None        2500
# 3        4      Ramya         2    1300        2.0  None        1800
# 4        5      Meena         3   20000        3.0  None       20500
# 5        6      Ashok         1    3000        1.0  None        3500
# 6        7      Abdul         3   20000        1.0  None       20500
# 7        8      Ramya         4   10000        2.0  None       10500
# 8        9      Raghu         5    8000        3.0  None        8500
# 9       10     Arvind         1     280        3.0  None         780
# 10      11     Akshay         4    8888        1.0  None        9388
# 11      12       John         0    2200        1.0  None        2700
# 12      13    Abinaya         4    2100        2.0  None        2600
# ...

# %%
df_fill = df["branch_id"].fillna(mod,inplace = True)
print(df.to_string())
# Out:
#     emp_id      ename  job_desc  salary  branch_id date_  new_salary
# 0        1        Ram         0    1000        2.0  None        1500
# 1        2     Harini         1    2500        2.0  None        3000
# 2        3     George         2    2000        1.0  None        2500
# 3        4      Ramya         2    1300        2.0  None        1800
# 4        5      Meena         3   20000        3.0  None       20500
# 5        6      Ashok         1    3000        1.0  None        3500
# 6        7      Abdul         3   20000        1.0  None       20500
# 7        8      Ramya         4   10000        2.0  None       10500
# 8        9      Raghu         5    8000        3.0  None        8500
# 9       10     Arvind         1     280        3.0  None         780
# 10      11     Akshay         4    8888        1.0  None        9388
# 11      12       John         0    2200        1.0  None        2700
# 12      13    Abinaya         4    2100        2.0  None        2600
# ...

# %%
df
# Out:
#     emp_id      ename  job_desc  salary  branch_id date_  new_salary
# 0        1        Ram         0    1000        2.0  None        1500
# 1        2     Harini         1    2500        2.0  None        3000
# 2        3     George         2    2000        1.0  None        2500
# 3        4      Ramya         2    1300        2.0  None        1800
# 4        5      Meena         3   20000        3.0  None       20500
# 5        6      Ashok         1    3000        1.0  None        3500
# 6        7      Abdul         3   20000        1.0  None       20500
# 7        8      Ramya         4   10000        2.0  None       10500
# 8        9      Raghu         5    8000        3.0  None        8500
# 9       10     Arvind         1     280        3.0  None         780
# 10      11     Akshay         4    8888        1.0  None        9388
# 11      12       John         0    2200        1.0  None        2700
# 12      13    Abinaya         4    2100        2.0  None        2600
# ...

# %%
df.to_csv("employee_de.csv")

# %%
x = pd.read_csv("employee_de.csv")
x
# Out:
#     Unnamed: 0  emp_id      ename  job_desc  salary  branch_id  date_  \
# 0            0       1        Ram         0    1000        2.0    NaN
# 1            1       2     Harini         1    2500        2.0    NaN
# 2            2       3     George         2    2000        1.0    NaN
# 3            3       4      Ramya         2    1300        2.0    NaN
# 4            4       5      Meena         3   20000        3.0    NaN
# 5            5       6      Ashok         1    3000        1.0    NaN
# 6            6       7      Abdul         3   20000        1.0    NaN
# 7            7       8      Ramya         4   10000        2.0    NaN
# 8            8       9      Raghu         5    8000        3.0    NaN
# 9            9      10     Arvind         1     280        3.0    NaN
# 10          10      11     Akshay         4    8888        1.0    NaN
# 11          11      12       John         0    2200        1.0    NaN
# ...

# %%
from IPython.display import display, FileLink, FileLinks

# %%
df.to_csv('employeedata.csv', index=False)

# %%
display(FileLink('employeedata.csv'))
# Out:
# C:\Users\USER\employeedata.csv
